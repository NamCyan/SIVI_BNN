# %% [markdown]
# **Test code**

# %%
import numpy as np
import torch
c = torch.ones([1,5])
a = 5
b = 4

print(torch.logsumexp(c, dim=1))
#print(torch.cat([c,b]))

# %% [markdown]
# **Clone SIVI_BNN**

# %%
#!git clone https://github.com/NamCyan/SIVI_BNN.git

# %% [markdown]
# **Click- Ctrl + Shilf + I**
# ```
# function ClickConnect(){
# console.log("Working");
# document.querySelector("colab-toolbar-button#connect").click()
# }
# setInterval(ClickConnect,60000)
# ```

# %%
# %cd ./drive/My\ Drive/SIVI_BNN/SIVI_BNN
# Out:
# /content/drive/My Drive
# /content/drive/My Drive/SIVI_BNN/SIVI_BNN

# %% [markdown]
# # Experiment

# %% [markdown]
# 1. **Baseline**

# %%
# !python bnn_baseline.py

# %% [markdown]
# 2. **SIVI_BNN for UCI dataset**

# %%
# !python SIVI_4_BNN_UCI.py

# %% [markdown]
# 3. **SIVI BNN for MNIST dataset**

# %%
# !python SIVI_4_BNN_MNIST.py
