# %%
import numpy as np
import torch
c = torch.ones([1,5])
a = 5
b = 4

print(torch.logsumexp(c, dim=1))
#print(torch.cat([c,b]))
# Out:
# tensor([2.6094])

# %%
#!git clone https://github.com/NamCyan/SIVI_BNN.git
# Out:
# Cloning into 'SIVI_BNN'...
# ...

# %%
rm -f ./.git/index.lock

# %%
# !git remote set-url origin https://NamCyan:Nkim1999@github.com/NamCyan/SIVI_BNN.git

# %%
# !git config --global user.name "NamCyan"
# !git config --global user.password "Nkim1999"
# !git config --global user.email "nkimxte@gmail.com"

# %%
# !git add .
# !git commit -m "update SIVI_mnist, uci"
# !git push origin master

# %% [markdown]
# ```
# function ClickConnect(){
# console.log("Working");
# document.querySelector("colab-toolbar-button#connect").click()
# }
# setInterval(ClickConnect,60000)
# ```

# %%
# %cd ./drive/My\ Drive
# %cd ./SIVI_BNN/SIVI_BNN
# Out:
# /content/drive/My Drive
# /content/drive/My Drive/SIVI_BNN/SIVI_BNN

# %%
# !python dataloader/uci.py

# %% [markdown]
# # BASELINE

# %%
# !python bnn_baseline.py

# %% [markdown]
# # SIVI BNN for UCI

# %%
# !python SIVI_4_BNN_UCI.py
# Out:
# Load data...
# UCI DATASET: CONCRETE
# TRAIN:torch.Size([741, 8])
# VALID:torch.Size([186, 8])
# TEST:torch.Size([103, 8])
#
# ********************************************************************************************************************************************************************************************************
# ----------------------------------------------------------------------------------------------------
# Net(
#   (fc1): SIVI_bayes_layer(
#     (SIVI): Net(
#       (drop): Dropout(p=0.005, inplace=False)
#       (relu): ReLU()
#       (fc1): Linear(in_features=50, out_features=100, bias=True)
#       (fc2): Linear(in_features=100, out_features=100, bias=True)
#       (fc3): Linear(in_features=100, out_features=9, bias=True)
#     )
#   )
#   (fc2): SIVI_bayes_layer(
#     (SIVI): Net(
#       (drop): Dropout(p=0.005, inplace=False)
#       (relu): ReLU()
#       (fc1): Linear(in_features=50, out_features=100, bias=True)
# ...

# %% [markdown]
# # SIVI BNN for MNIST

# %%
# !python SIVI_4_BNN.py
# Out:
# Load data...
# MNIST DATASET
# torch.Size([10000, 1, 28, 28]) torch.Size([10000])
# Done!
#
# ********************************************************************************************************************************************************************************************************
# ----------------------------------------------------------------------------------------------------
# Net(
#   (fc1): SIVI_bayes_layer(
#     (SIVI): Net(
#       (relu): ReLU()
#       (fc1): Linear(in_features=100, out_features=400, bias=True)
#       (fc2): Linear(in_features=400, out_features=400, bias=True)
#       (fc3): Linear(in_features=400, out_features=785, bias=True)
#     )
#   )
#   (fc2): SIVI_bayes_layer(
#     (SIVI): Net(
#       (relu): ReLU()
#       (fc1): Linear(in_features=100, out_features=400, bias=True)
#       (fc2): Linear(in_features=400, out_features=400, bias=True)
#       (fc3): Linear(in_features=400, out_features=401, bias=True)
#     )
#   )
# ...
